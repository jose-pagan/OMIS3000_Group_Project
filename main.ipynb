# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # County Data

# %%
county_data = pd.read_csv('county_info_2016.csv', encoding='latin-1')
county_data
# Out:
#      USPS  GEOID  ANSICODE                 NAME       ALAND      AWATER  \
# 0      AL   1001    161526       Autauga County  1539609015    25749942
# 1      AL   1003    161527       Baldwin County  4117584019  1133130502
# 2      AL   1005    161528       Barbour County  2291818680    50864677
# 3      AL   1007    161529          Bibb County  1612481559     9287974
# 4      AL   1009    161530        Blount County  1670041875    15077458
# ...   ...    ...       ...                  ...         ...         ...
# 3215   PR  72145   1804553  Vega Baja Municipio   118766803    57805868
# 3216   PR  72147   1804554    Vieques Municipio   131527813   552206400
# 3217   PR  72149   1804555   Villalba Municipio    92298573     3622637
# 3218   PR  72151   1804556    Yabucoa Municipio   143005178    72592521
# 3219   PR  72153   1804557      Yauco Municipio   175371915     1625260
#
#       ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 0        594.446        9.942  32.532237
# ...

# %% [markdown]
# ## Columns

# %%
county_data.columns
# Out:
# Index(['USPS', 'GEOID', 'ANSICODE', 'NAME', 'ALAND', 'AWATER', 'ALAND_SQMI',
#        'AWATER_SQMI', 'INTPTLAT',
#        'INTPTLONG                                                                                                               '],
#       dtype='object')

# %% [markdown]
# ## Select county information from CA, WA and OR

# %%
or_ca_wa_county_data = county_data[county_data['USPS'].str.contains("CA|WA|OR")]
or_ca_wa_county_data
# Out:
#      USPS  GEOID  ANSICODE                NAME        ALAND      AWATER  \
# 186    CA   6001   1675839      Alameda County   1914242789   212979931
# 187    CA   6003   1675840       Alpine County   1912292633    12557304
# 188    CA   6005   1675841       Amador County   1539933576    29470568
# 189    CA   6007   1675842        Butte County   4238423343   105325812
# 190    CA   6009   1675885    Calaveras County   2641820834    43806026
# ...   ...    ...       ...                 ...          ...         ...
# 2987   WA  53069   1513275    Wahkiakum County    680956787    61588406
# 2988   WA  53071   1531819  Walla Walla County   3289366722    74935920
# 2989   WA  53073   1529224      Whatcom County   5459395531  1028184731
# 2990   WA  53075   1533501      Whitman County   5592428647    48281266
# 2991   WA  53077   1531929       Yakima County  11122757385    41168171
#
#       ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 186      739.093       82.232  37.647139
# ...

# %% [markdown]
# ## Read US Droughts CSV

# %%
us_droughts_data = pd.read_csv('us-droughts.csv')
us_droughts_data
# Out:
#         releaseDate   FIPS                  county state    NONE     D0   D1  \
# 0        2000-11-07   2013  Aleutians East Borough    AK  100.00   0.00  0.0
# 1        2000-10-31   2013  Aleutians East Borough    AK  100.00   0.00  0.0
# 2        2000-10-24   2013  Aleutians East Borough    AK  100.00   0.00  0.0
# 3        2000-10-17   2013  Aleutians East Borough    AK  100.00   0.00  0.0
# 4        2000-10-10   2013  Aleutians East Borough    AK  100.00   0.00  0.0
# ...             ...    ...                     ...   ...     ...    ...  ...
# 2829496  2015-12-08  56045           Weston County    WY   29.45  70.55  0.0
# 2829497  2015-12-01  56045           Weston County    WY   29.45  70.55  0.0
# 2829498  2015-11-24  56045           Weston County    WY   29.45  70.55  0.0
# 2829499  2015-11-17  56045           Weston County    WY   29.45  70.55  0.0
# 2829500  2015-11-10  56045           Weston County    WY   30.70  69.30  0.0
#
# ...

# %% [markdown]
# ## Select CA, WA and OR rows

# %%
or_ca_wa_droughts_data = us_droughts_data[us_droughts_data['state'].str.contains("CA|WA|OR")]
or_ca_wa_droughts_data
# Out:
#         releaseDate   FIPS          county state   NONE     D0     D1     D2  \
# 8280     2000-11-07   6001  Alameda County    CA  100.0    0.0    0.0   0.00
# 8281     2000-10-31   6001  Alameda County    CA  100.0    0.0    0.0   0.00
# 8282     2000-10-24   6001  Alameda County    CA  100.0    0.0    0.0   0.00
# 8283     2000-10-17   6001  Alameda County    CA  100.0    0.0    0.0   0.00
# 8284     2000-10-10   6001  Alameda County    CA  100.0    0.0    0.0   0.00
# ...             ...    ...             ...   ...    ...    ...    ...    ...
# 2821696  2015-12-08  53077   Yakima County    WA    0.0  100.0   98.8  94.60
# 2821697  2015-12-01  53077   Yakima County    WA    0.0  100.0  100.0  98.90
# 2821698  2015-11-24  53077   Yakima County    WA    0.0  100.0  100.0  98.90
# 2821699  2015-11-17  53077   Yakima County    WA    0.0  100.0  100.0  98.90
# 2821700  2015-11-10  53077   Yakima County    WA    0.0  100.0  100.0  98.78
#
# ...

# %% [markdown]
# ## Read NFL Data from [Kaggle - 2022 NFL Team Offense](https://www.kaggle.com/datasets/mattop/2022nfl-team-offense)

# %%
# dictionary of NFL Data Frames
# nfl{}
# nfloffenseweek3.csv <class 'pandas.core.frame.DataFrame'>
# nfloffenseweek4.csv <class 'pandas.core.frame.DataFrame'>
# nfloffenseweek5.csv <class 'pandas.core.frame.DataFrame'>
#
nfl = {}

for i in range(3, 6):
    filename = f'nfloffenseweek{i}.csv'
    nfl[filename.strip('.csv').strip('nfloffense')] = pd.read_csv(filename)
nfl["week3"]
nfl["week4"]
nfl["week5"]
# Out:
#     rank                   team  games  points_scored  total_yards  \
# 0      1          Detroit Lions      4            140         1747
# 1      2     Kansas City Chiefs      4            129         1539
# 2      3       Baltimore Ravens      4            119         1437
# 3      4    Philadelphia Eagles      4            115         1742
# 4      5          Buffalo Bills      4            114         1650
# 5      6       Cleveland Browns      4            105         1539
# 6      7   Jacksonville Jaguars      4            105         1346
# 7      8        Atlanta Falcons      4            103         1396
# 8      9         Miami Dolphins      4             98         1444
# 9     10      Las Vegas Raiders      4             96         1425
# 10    11       Seattle Seahawks      4             95         1444
# 11    12   Los Angeles Chargers      4             92         1487
# 12    13     Cincinnati Bengals      4             91         1387
# ...
